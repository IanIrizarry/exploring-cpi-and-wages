# %%
import pandas as pd

# %%
df1 = pd.read_excel('data/edited-data/news-release-table1-202007.xlsx')
df2 = pd.read_excel('data/edited-data/news-release-table2-202007.xlsx')
df3 = pd.read_excel('data/edited-data/news-release-table3-202007.xlsx')
df4 = pd.read_excel('data/edited-data/news-release-table4-202007.xlsx')
df5 = pd.read_excel('data/edited-data/news-release-table5-202007.xlsx')
df6 = pd.read_excel('data/edited-data/news-release-table6-202007.xlsx')
df7 = pd.read_excel('data/edited-data/news-release-table7-202007.xlsx')
df8 = pd.read_excel('data/edited-data/cpi-u-202007.xlsx')

# %%
df1.head(20)
# Out:
#                              Expenditure category  \
# 0                                       All items
# 1                                            Food
# 2                                    Food at home
# 3                     Cereals and bakery products
# 4                  Meats, poultry, fish, and eggs
# 5                      Dairy and related products
# 6                           Fruits and vegetables
# 7   Nonalcoholic beverages and beverage materials
# 8                              Other food at home
# 9                          Food away from home(1)
# 10                                            NaN
# 11                                         Energy
# 12                             Energy commodities
# 13                                       Fuel oil
# 14                                     Motor fuel
# 15                           Gasoline (all types)
# 16                                Energy services
# 17                                    Electricity
# ...

# %%
df2.head(20)
# Out:
#                               Expenditure category  \
# 0                                              NaN
# 1                                        All items
# 2                                             Food
# 3                                     Food at home
# 4                      Cereals and bakery products
# 5                      Cereals and cereal products
# 6                   Flour and prepared flour mixes
# 7                              Breakfast cereal(1)
# 8                         Rice, pasta, cornmeal(1)
# 9                                    Rice(1)(2)(3)
# 10                              Bakery products(1)
# 11                                     Bread(1)(2)
# 12                               White bread(1)(3)
# 13                    Bread other than white(1)(3)
# 14               Fresh biscuits, rolls, muffins(2)
# 15                    Cakes, cupcakes, and cookies
# 16                                   Cookies(1)(3)
# ...

# %%
df3.head(20)
# Out:
#                             Special aggregate indexes  \
# 0                                 All items less food
# 1                              All items less shelter
# 2                     All items less food and shelter
# 3            All items less food, shelter, and energy
# 4   All items less food, shelter, energy, and used...
# 5                         All items less medical care
# 6                               All items less energy
# 7                                         Commodities
# 8   Commodities less food, energy, and used cars a...
# 9                               Commodities less food
# 10                Commodities less food and beverages
# 11                                           Services
# 12                   Services less rent of shelter(1)
# 13                Services less medical care services
# 14                                           Durables
# 15                                        Nondurables
# ...

# %%
df4.head(20)
# Out:
#                              Area Pricing\nSchedule(1)  \
# 0               U.S. city average                    M
# 1                       Northeast                    M
# 2        Northeast - Size Class A                    M
# 3   Northeast - Size Class B/C(3)                    M
# 4                  New England(4)                    M
# 5              Middle Atlantic(4)                    M
# 6                         Midwest                    M
# 7          Midwest - Size Class A                    M
# 8     Midwest - Size Class B/C(3)                    M
# 9           East North Central(4)                    M
# 10          West North Central(4)                    M
# 11                          South                    M
# 12           South - Size Class A                    M
# 13      South - Size Class B/C(3)                    M
# 14              South Atlantic(4)                    M
# 15          East South Central(4)                    M
# ...

# %%
df5.head(20)
# Out:
#         Month Year  Unadjusted 1-month percent change C-CPI-U(1)  \
# 0    December 2007                                           NaN
# 1    December 2008                                           NaN
# 2    December 2009                                           NaN
# 3    December 2010                                           NaN
# 4    December 2011                                           NaN
# 5    December 2012                                           NaN
# 6    December 2013                                           NaN
# 7    December 2014                                           NaN
# 8    December 2015                                           NaN
# 9    December 2016                                           NaN
# 10   December 2017                                           NaN
# 11    January 2018                                           0.5
# 12   February 2018                                           0.4
# ...

# %%
df6.head(20)
# Out:
#                               Expenditure category  \
# 0                                        All items
# 1                                             Food
# 2                                     Food at home
# 3                      Cereals and bakery products
# 4                      Cereals and cereal products
# 5                   Flour and prepared flour mixes
# 6                              Breakfast cereal(4)
# 7                         Rice, pasta, cornmeal(4)
# 8                                    Rice(4)(5)(6)
# 9                               Bakery products(4)
# 10                                     Bread(4)(5)
# 11                               White bread(4)(6)
# 12                    Bread other than white(4)(6)
# 13               Fresh biscuits, rolls, muffins(5)
# 14                    Cakes, cupcakes, and cookies
# 15                                   Cookies(4)(6)
# 16                  Fresh cakes and cupcakes(4)(6)
# ...

# %%
df7.head(20)
# Out:
#                            Expenditure category  \
# 0                                     All items
# 1                                          Food
# 2                                  Food at home
# 3                   Cereals and bakery products
# 4                   Cereals and cereal products
# 5                Flour and prepared flour mixes
# 6                              Breakfast cereal
# 7                         Rice, pasta, cornmeal
# 8                                    Rice(4)(5)
# 9                               Bakery products
# 10                                     Bread(4)
# 11                               White bread(5)
# 12                    Bread other than white(5)
# 13            Fresh biscuits, rolls, muffins(4)
# 14                 Cakes, cupcakes, and cookies
# 15                                   Cookies(5)
# 16                  Fresh cakes and cupcakes(5)
# 17                        Other bakery products
# ...

# %%
df8.head(20)
# Out:
#                               Expenditure category  \
# 0                                        All items
# 1                                             Food
# 2                                     Food at home
# 3                      Cereals and bakery products
# 4                      Cereals and cereal products
# 5                   Flour and prepared flour mixes
# 6                              Breakfast cereal(4)
# 7                         Rice, pasta, cornmeal(4)
# 8                                    Rice(4)(5)(6)
# 9                               Bakery products(4)
# 10                                     Bread(4)(5)
# 11                               White bread(4)(6)
# 12                    Bread other than white(4)(6)
# 13               Fresh biscuits, rolls, muffins(5)
# 14                    Cakes, cupcakes, and cookies
# 15                                   Cookies(4)(6)
# 16                  Fresh cakes and cupcakes(4)(6)
# ...
